# %% [markdown]
# #1-Import

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/MY PROJECT/7-RECOMENDATION/Google Play/googleplaystore.csv')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# Çocukta olan başlıklar: Author - book_title - ratings - genre
#
# Bizde olan başlıklar: ...... - app - rating - genre
#
# yazar yerine ne koyabiliriz? - category? price? type?

# %% [markdown]
# #2-Data Understanding

# %%
# We don't need these columns

df1 = df.drop(columns=["Android Ver", "Current Ver", "Last Updated", "Type", "Size", "Content Rating", "Category" ], axis=1, inplace=False)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   App       10841 non-null  object
#  1   Rating    9367 non-null   float64
#  2   Reviews   10841 non-null  object
#  3   Installs  10841 non-null  object
#  4   Price     10841 non-null  object
#  5   Genres    10841 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 508.3+ KB

# %% [markdown]
# ##2.1 Def

# %%
# Remove Plus Function
def remove_plus(df, col):
    df[col] = df[col].astype(str).str.replace('+', '', regex=False)

# %%
# Remove Comma Function
def remove_commas(df, col):
    df[col] = df[col].str.replace(',', '')

# %%
# Covert Numeric Function
def convert_to_numeric(df, col):
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %% [markdown]
# ## 2.2 Genres

# %%
print( len(df1['Genres'].unique()) , "Genres")

print("\n", df1['Genres'].unique())
# Out:
# 120 Genres
#
#  ['Art & Design' 'Art & Design;Pretend Play' 'Art & Design;Creativity'
#  'Art & Design;Action & Adventure' 'Auto & Vehicles' 'Beauty'
#  'Books & Reference' 'Business' 'Comics' 'Comics;Creativity'
#  'Communication' 'Dating' 'Education;Education' 'Education'
#  'Education;Creativity' 'Education;Music & Video'
#  'Education;Action & Adventure' 'Education;Pretend Play'
#  'Education;Brain Games' 'Entertainment' 'Entertainment;Music & Video'
#  'Entertainment;Brain Games' 'Entertainment;Creativity' 'Events' 'Finance'
#  'Food & Drink' 'Health & Fitness' 'House & Home' 'Libraries & Demo'
#  'Lifestyle' 'Lifestyle;Pretend Play' 'Adventure;Action & Adventure'
#  'Arcade' 'Casual' 'Card' 'Casual;Pretend Play' 'Action' 'Strategy'
#  'Puzzle' 'Sports' 'Music' 'Word' 'Racing' 'Casual;Creativity'
#  'Casual;Action & Adventure' 'Simulation' 'Adventure' 'Board' 'Trivia'
#  'Role Playing' 'Simulation;Education' 'Action;Action & Adventure'
# ...

# %%
df1.Genres.value_counts().head(10)
# Out:
# Tools              842
# Entertainment      623
# Education          549
# Medical            463
# Business           460
# Productivity       424
# Sports             398
# Personalization    392
# Communication      387
# Lifestyle          381
# Name: Genres, dtype: int64

# %%
df1.Genres.value_counts().tail(10)
# Out:
# Tools;Education                      1
# Travel & Local;Action & Adventure    1
# Board;Pretend Play                   1
# Health & Fitness;Education           1
# Music & Audio;Music & Video          1
# Arcade;Pretend Play                  1
# Card;Brain Games                     1
# Lifestyle;Pretend Play               1
# Comics;Creativity                    1
# Strategy;Creativity                  1
# Name: Genres, dtype: int64

# %%
df1['Genres'] = df1['Genres'].str.split(';').str[0]

# %%
print( len(df1['Genres'].unique()) , "Genres")

print("\n", df1['Genres'].unique())
# Out:
# 49 Genres
#
#  ['Art & Design' 'Auto & Vehicles' 'Beauty' 'Books & Reference' 'Business'
#  'Comics' 'Communication' 'Dating' 'Education' 'Entertainment' 'Events'
#  'Finance' 'Food & Drink' 'Health & Fitness' 'House & Home'
#  'Libraries & Demo' 'Lifestyle' 'Adventure' 'Arcade' 'Casual' 'Card'
#  'Action' 'Strategy' 'Puzzle' 'Sports' 'Music' 'Word' 'Racing'
#  'Simulation' 'Board' 'Trivia' 'Role Playing' 'Educational'
#  'Music & Audio' 'Video Players & Editors' 'Medical' 'Social' 'Shopping'
#  'Photography' 'Travel & Local' 'Tools' 'Personalization' 'Productivity'
#  'Parenting' 'Weather' 'News & Magazines' 'Maps & Navigation' 'Casino'
#  'February 11, 2018']

# %%
df1['Genres'].replace('Music & Audio', 'Music',inplace = True)
df1['Genres'].replace('News & Magazines', 'News',inplace = True)
df1['Genres'].replace('Maps & Navigation', 'Maps',inplace = True)
df1['Genres'].replace('Travel & Local', 'Travel',inplace = True)
df1['Genres'].replace('Health & Fitness', 'Health',inplace = True)
df1['Genres'].replace('House & Home', 'Home',inplace = True)
df1['Genres'].replace('Auto & Vehicles', 'Vehicles',inplace = True)

# %%
print( len(df1['Genres'].unique()) , "Genres")

print("\n", df1['Genres'].unique())
# Out:
# 48 Genres
#
#  ['Art & Design' 'Vehicles' 'Beauty' 'Books & Reference' 'Business'
#  'Comics' 'Communication' 'Dating' 'Education' 'Entertainment' 'Events'
#  'Finance' 'Food & Drink' 'Health' 'Home' 'Libraries & Demo' 'Lifestyle'
#  'Adventure' 'Arcade' 'Casual' 'Card' 'Action' 'Strategy' 'Puzzle'
#  'Sports' 'Music' 'Word' 'Racing' 'Simulation' 'Board' 'Trivia'
#  'Role Playing' 'Educational' 'Video Players & Editors' 'Medical' 'Social'
#  'Shopping' 'Photography' 'Travel' 'Tools' 'Personalization'
#  'Productivity' 'Parenting' 'Weather' 'News' 'Maps' 'Casino'
#  'February 11, 2018']

# %%
df1genre = df1.loc[lambda df1: df1['Genres'] == "February 11, 2018"]
df1genre
# Out:
#                                            App  Rating Reviews Installs  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame    19.0    3.0M     Free
#
#           Price             Genres
# 10472  Everyone  February 11, 2018

# %%
df1 = df1[df1.Genres != "February 11, 2018"	]

# %%
print( len(df1['Genres'].unique()) , "Genres")

print("\n", df1['Genres'].unique())
# Out:
# 47 Genres
#
#  ['Art & Design' 'Vehicles' 'Beauty' 'Books & Reference' 'Business'
#  'Comics' 'Communication' 'Dating' 'Education' 'Entertainment' 'Events'
#  'Finance' 'Food & Drink' 'Health' 'Home' 'Libraries & Demo' 'Lifestyle'
#  'Adventure' 'Arcade' 'Casual' 'Card' 'Action' 'Strategy' 'Puzzle'
#  'Sports' 'Music' 'Word' 'Racing' 'Simulation' 'Board' 'Trivia'
#  'Role Playing' 'Educational' 'Video Players & Editors' 'Medical' 'Social'
#  'Shopping' 'Photography' 'Travel' 'Tools' 'Personalization'
#  'Productivity' 'Parenting' 'Weather' 'News' 'Maps' 'Casino']

# %% [markdown]
# ##2.3 Price

# %%
print( len(df1['Price'].unique()) , "Price")

print("\n", df1['Price'].unique())
# Out:
# 92 Price
#
#  ['0' '$4.99' '$3.99' '$6.99' '$1.49' '$2.99' '$7.99' '$5.99' '$3.49'
#  '$1.99' '$9.99' '$7.49' '$0.99' '$9.00' '$5.49' '$10.00' '$24.99'
#  '$11.99' '$79.99' '$16.99' '$14.99' '$1.00' '$29.99' '$12.99' '$2.49'
#  '$10.99' '$1.50' '$19.99' '$15.99' '$33.99' '$74.99' '$39.99' '$3.95'
#  '$4.49' '$1.70' '$8.99' '$2.00' '$3.88' '$25.99' '$399.99' '$17.99'
#  '$400.00' '$3.02' '$1.76' '$4.84' '$4.77' '$1.61' '$2.50' '$1.59' '$6.49'
#  '$1.29' '$5.00' '$13.99' '$299.99' '$379.99' '$37.99' '$18.99' '$389.99'
#  '$19.90' '$8.49' '$1.75' '$14.00' '$4.85' '$46.99' '$109.99' '$154.99'
#  '$3.08' '$2.59' '$4.80' '$1.96' '$19.40' '$3.90' '$4.59' '$15.46' '$3.04'
#  '$4.29' '$2.60' '$3.28' '$4.60' '$28.99' '$2.95' '$2.90' '$1.97'
#  '$200.00' '$89.99' '$2.56' '$30.99' '$3.61' '$394.99' '$1.26' '$1.20'
#  '$1.04']

# %%
# Remove Plus Function
def remove_dolars(df, col):
    df[col] = df[col].astype(str).str.replace('$', '', regex=False)

# %%
remove_dolars(df1, "Price")

# %%
print( len(df1['Price'].unique()) , "Price")

print("\n", df1['Price'].unique())
# Out:
# 92 Price
#
#  ['0' '4.99' '3.99' '6.99' '1.49' '2.99' '7.99' '5.99' '3.49' '1.99' '9.99'
#  '7.49' '0.99' '9.00' '5.49' '10.00' '24.99' '11.99' '79.99' '16.99'
#  '14.99' '1.00' '29.99' '12.99' '2.49' '10.99' '1.50' '19.99' '15.99'
#  '33.99' '74.99' '39.99' '3.95' '4.49' '1.70' '8.99' '2.00' '3.88' '25.99'
#  '399.99' '17.99' '400.00' '3.02' '1.76' '4.84' '4.77' '1.61' '2.50'
#  '1.59' '6.49' '1.29' '5.00' '13.99' '299.99' '379.99' '37.99' '18.99'
#  '389.99' '19.90' '8.49' '1.75' '14.00' '4.85' '46.99' '109.99' '154.99'
#  '3.08' '2.59' '4.80' '1.96' '19.40' '3.90' '4.59' '15.46' '3.04' '4.29'
#  '2.60' '3.28' '4.60' '28.99' '2.95' '2.90' '1.97' '200.00' '89.99' '2.56'
#  '30.99' '3.61' '394.99' '1.26' '1.20' '1.04']

# %%
print(df1["Price"].value_counts() / df1.shape[0] * 100)
# Out:
# 0        92.619926
# 0.99      1.365314
# 2.99      1.190037
# 1.99      0.673432
# 4.99      0.664207
#            ...
# 19.90     0.009225
# 1.75      0.009225
# 14.00     0.009225
# 4.85      0.009225
# 1.04      0.009225
# Name: Price, Length: 92, dtype: float64

# %%
print(df1["Price"].value_counts())
# Out:
# 0        10040
# 0.99       148
# 2.99       129
# 1.99        73
# 4.99        72
#          ...
# 19.90        1
# 1.75         1
# 14.00        1
# 4.85         1
# 1.04         1
# Name: Price, Length: 92, dtype: int64

# %% [markdown]
# ## 2.4 Rating

# %%
df1.isnull().sum()
# Out:
# App            0
# Rating      1474
# Reviews        0
# Installs       0
# Price          0
# Genres         0
# dtype: int64

# %%
df1["Rating"].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838     True
# 10839    False
# 10840    False
# Name: Rating, Length: 10840, dtype: bool

# %%
print(df1["Rating"].value_counts() / df1.shape[0] * 100)
# Out:
# 4.4    10.230627
# 4.3     9.926199
# 4.5     9.575646
# 4.2     8.782288
# 4.6     7.592251
# 4.1     6.531365
# 4.0     5.239852
# 4.7     4.603321
# 3.9     3.560886
# 3.8     2.795203
# 5.0     2.527675
# 3.7     2.204797
# 4.8     2.158672
# 3.6     1.605166
# 3.5     1.503690
# 3.4     1.180812
# 3.3     0.940959
# 4.9     0.802583
# 3.0     0.765683
# 3.1     0.636531
# 3.2     0.590406
# 2.9     0.415129
# 2.8     0.387454
# 2.7     0.230627
# 2.6     0.230627
# 2.5     0.193727
# 2.3     0.184502
# 2.4     0.175277
# 1.0     0.147601
# 2.2     0.129151
# 1.9     0.119926
# 2.0     0.110701
# 1.7     0.073801
# 1.8     0.073801
# 2.1     0.073801
# 1.6     0.036900
# 1.4     0.027675
# 1.5     0.027675
# 1.2     0.009225
# Name: Rating, dtype: float64

# %%
df1_rating_nan = df1.loc[lambda df1: df1["Rating"].isnull() == True]
df1_rating_nan
# Out:
#                                        App  Rating Reviews  Installs Price  \
# 23                  Mcqueen Coloring pages     NaN      61  100,000+     0
# 113              Wrinkles and rejuvenation     NaN     182  100,000+     0
# 123                 Manicure - nail design     NaN     119   50,000+     0
# 126           Skin Care and Natural Beauty     NaN     654  100,000+     0
# 129    Secrets of beauty, youth and health     NaN      77   10,000+     0
# ...                                    ...     ...     ...       ...   ...
# 10824                            Cardio-FR     NaN      67   10,000+     0
# 10825                   Naruto & Boruto FR     NaN       7      100+     0
# 10831             payermonstationnement.fr     NaN      38    5,000+     0
# 10835                             FR Forms     NaN       0       10+     0
# 10838               Parkinson Exercices FR     NaN       3    1,000+     0
#
#              Genres
# 23     Art & Design
# 113          Beauty
# ...

# %%
df1_rating_nan
print(df1_rating_nan["Installs"].value_counts() / df1_rating_nan.shape[0] * 100)
# Out:
# 100+          27.815468
# 10+           21.506106
# 1,000+        13.161465
# 50+           10.108548
# 500+           8.751696
# 5+             4.952510
# 1+             4.341927
# 5,000+         3.052917
# 10,000+        2.985075
# 100,000+       1.289009
# 0+             0.949796
# 50,000+        0.814111
# 1,000,000+     0.135685
# 500,000+       0.067843
# 0              0.067843
# Name: Installs, dtype: float64

# %%
df1['Rating'].median(skipna=True)
# Out:
# 4.3

# %%
df1["Rating"].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838     True
# 10839    False
# 10840    False
# Name: Rating, Length: 10840, dtype: bool

# %%
df1.Rating.fillna(3, inplace=True)

# %%
df1_rating_nan = df1.loc[lambda df1: df1["Rating"].isnull() == True]
df1_rating_nan
# Out:
# Empty DataFrame
# Columns: [App, Rating, Reviews, Installs, Price, Genres]
# Index: []

# %% [markdown]
# ## 2.5 Installs

# %%
df1.head()
# Out:
#                                                  App  Rating Reviews  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook     4.1     159
# 1                                Coloring book moana     3.9     967
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...     4.7   87510
# 3                              Sketch - Draw & Paint     4.5  215644
# 4              Pixel Draw - Number Art Coloring Book     4.3     967
#
#       Installs Price        Genres
# 0      10,000+     0  Art & Design
# 1     500,000+     0  Art & Design
# 2   5,000,000+     0  Art & Design
# 3  50,000,000+     0  Art & Design
# 4     100,000+     0  Art & Design

# %%
remove_plus(df1, "Installs")

# %%
df1.head()
# Out:
#                                                  App  Rating Reviews  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook     4.1     159
# 1                                Coloring book moana     3.9     967
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...     4.7   87510
# 3                              Sketch - Draw & Paint     4.5  215644
# 4              Pixel Draw - Number Art Coloring Book     4.3     967
#
#      Installs Price        Genres
# 0      10,000     0  Art & Design
# 1     500,000     0  Art & Design
# 2   5,000,000     0  Art & Design
# 3  50,000,000     0  Art & Design
# 4     100,000     0  Art & Design

# %%
FilterGrid = df1.loc[lambda df1: df1['App'] == "FilterGrid - Cam&Photo Editor"]
FilterGrid
# Out:
#                                  App  Rating Reviews   Installs Price  \
# 2923   FilterGrid - Cam&Photo Editor     4.6  126337  1,000,000     0
# 10118  FilterGrid - Cam&Photo Editor     4.6  126338  1,000,000     0
#
#             Genres
# 2923   Photography
# 10118  Photography

# %%
print( len(df1['App'].unique()) , "App")
# Out:
# 9658 App

# %%
df1 = df1.sort_values('Reviews', ascending=False).drop_duplicates('App').sort_index()

# %%
FilterGrid = df1.loc[lambda df1: df1['App'] == "FilterGrid - Cam&Photo Editor"]
FilterGrid
# Out:
#                                  App  Rating Reviews   Installs Price  \
# 10118  FilterGrid - Cam&Photo Editor     4.6  126338  1,000,000     0
#
#             Genres
# 10118  Photography

# %%
df1.to_csv("cleaned.csv")

# %% [markdown]
# #3-Recommendation

# %%
def recommender(genre):
    '''
    Recomment top rated apps from same genre.
    If only single app from that genre -> return randomly from alltime top10
    
    '''
    
    top = df1[df1['Genres'] == genre].sort_values(by='Rating', ascending=False)
    if top.shape[0] > 1:
        return dict(top.iloc[0])
    else:
        return dict(df.sort_values(by='ratings', ascending=False).iloc[:10].sample(1).squeeze())

# %%
df['Genres'].value_counts()
# Out:
# Tools                     842
# Entertainment             623
# Education                 549
# Medical                   463
# Business                  460
#                          ...
# Arcade;Pretend Play         1
# Card;Brain Games            1
# Lifestyle;Pretend Play      1
# Comics;Creativity           1
# Strategy;Creativity         1
# Name: Genres, Length: 120, dtype: int64

# %%
recommender('Tools')
# Out:
# {'App': 'BK Formula Calculator',
#  'Rating': 5.0,
#  'Reviews': '6',
#  'Installs': '100+',
#  'Price': '0',
#  'Genres': 'Tools'}

# %%
recommender('Entertainment')
# Out:
# {'App': 'EC Fairgrounds',
#  'Rating': 5.0,
#  'Reviews': '3',
#  'Installs': '500+',
#  'Price': '0',
#  'Genres': 'Entertainment'}

# %%
df1.sort_values(by='Rating', ascending=False).iloc[:10]
# Out:
#                                      App  Rating Reviews Installs Price  \
# 9039                       Chronolink DX     5.0       7      10+  0.99
# 6700                    Brick Breaker BR     5.0       7       5+     0
# 8874                 Dt. Jyothi Srinivas     5.0      18     100+     0
# 8869                        DT CLOTHINGS     5.0       1      10+     0
# 6055                         Movement BE     5.0      20     100+     0
# 2445                      Labs on Demand     5.0       1      10+     0
# 1030                          Prosperity     5.0      16     100+     0
# 1028                    SUMMER SONIC app     5.0       4     500+     0
# 5685  Jobs in Canada - Emplois au Canada     5.0       2   1,000+     0
# 1547                        Eternal life     5.0      26   1,000+     0
#
#                 Genres
# 9039            Puzzle
# 6700            Arcade
# 8874            Health
# 8869          Shopping
# 6055            Social
# 2445           Medical
# ...

# %%
something = df1.sample(6)

# %%
[dict(something.iloc[i]) for i in range(6)]
# Out:
# [{'App': 'OfficeSuite Pro + PDF (Trial)',
#   'Rating': 4.2,
#   'Reviews': '88073',
#   'Installs': '10,000,000+',
#   'Price': '0',
#   'Genres': 'Business'},
#  {'App': 'Sumine side dish - dish recipe side dish',
#   'Rating': 3.0,
#   'Reviews': '82',
#   'Installs': '10,000+',
#   'Price': '0',
#   'Genres': 'Food & Drink'},
#  {'App': 'CIRCLE K',
#   'Rating': 4.4,
#   'Reviews': '9140',
#   'Installs': '500,000+',
#   'Price': '0',
#   'Genres': 'Shopping'},
#  {'App': 'E.G. Chess',
#   'Rating': 4.3,
#   'Reviews': '56',
#   'Installs': '1,000+',
#   'Price': '0.99',
#   'Genres': 'Board'},
#  {'App': 'Little Big City 2',
#   'Rating': 4.4,
#   'Reviews': '344383',
#   'Installs': '10,000,000+',
#   'Price': '0',
#   'Genres': 'Casual'},
#  {'App': 'Lollipop Keyboard L Pro',
#   'Rating': 3.6,
#   'Reviews': '5525',
#   'Installs': '500,000+',
#   'Price': '0',
#   'Genres': 'Personalization'}]
